# %% [raw]
# ---
# title: Overview
# aliases:
#   - ../index.html
# jupyter:
#   kernelspec:
#     display_name: Python 3 (ipykernel)
#     language: python
#     name: python3
# ---

# %% [markdown]
# **script-widget** lets you ...
#
# {{< lipsum 1 >}}
#
# ## Installation
#
# ::: {.panel-tabset}
#
# ## pixi
#
# ```bash
# pixi workspace channel add munch-group
# pixi add script-widget
# ```
#
# ## conda
#
# ```bash
# conda install -c munch-group script-widget
# ```
#
# ## pip
#
# ```bash
# pip install script-widget
# ```
#
# :::
#
#
# ## Basic use
#
# ```python
#
# ```
#
# ## Some use case
#
# The [run_exercise function](`script_widget.executor.run_exercise`) runs a cell's source in a fresh, isolated namespace and returns an [ExerciseResult](`script_widget.executor.ExerciseResult`) capturing everything it produced.
#
# {{< lipsum 1 >}}

# %%
# from script_widget import run_exercise
# run_exercise("1 + 1")

# %% [markdown]
# {{< lipsum 1 >}}
#
# ```yaml
# contents:
#   - MdRenderer
# ```
#
# {{< lipsum 1 >}}
#
# ## Learning more
#
# Go [to the anvanced page](overview.ipynb) to learn how to ...
#
# * [Examples page](overview.ipynb): sites using quartodoc.
